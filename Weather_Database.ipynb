# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 713

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
#PLEASE SEE NEXT INPUT CELL FOR THIS PART

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
#code here are mostly repurposed from weatherpy.ipynb
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&appid=" + weather_api_key

#create list for holding the cities
city_data = []

#print beginning of logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#create counters
record_count = 1
set_count = 1

#loop through all cities in our list
for i,city in enumerate (cities):
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
        time.sleep(60)

    #create endpoint url for each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #log the url, record and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count +=1

    # Run an API request for each of the cities
    try:
        #parse json and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        #convert the date to iso std
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description" : city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,})
    
        # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

#indicate data loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | salalah
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | kahului
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | bathsheba
# Processing Record 10 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 1 | sarauli
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 1 | ostrovnoy
# Processing Record 15 of Set 1 | souillac
# Processing Record 16 of Set 1 | musoma
# Processing Record 17 of Set 1 | mantua
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | kavieng
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | luderitz
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | hofn
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | nanortalik
# Processing Record 30 of Set 1 | azimur
# City not found. Skipping...
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | katsuura
# Processing Record 34 of Set 1 | westport
# Processing Record 35 of Set 1 | flinders
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | tigil
# Processing Record 38 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 1 | bethel
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | sinnamary
# Processing Record 43 of Set 1 | asau
# Processing Record 44 of Set 1 | kholm
# Processing Record 45 of Set 1 | kefamenanu
# Processing Record 46 of Set 1 | fortuna
# Processing Record 47 of Set 1 | norman wells
# Processing Record 48 of Set 1 | hasaki
# Processing Record 49 of Set 1 | spencer
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | kaitangata
# Processing Record 2 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 2 | eenhana
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | north bend
# Processing Record 6 of Set 2 | kashary
# Processing Record 7 of Set 2 | juneau
# Processing Record 8 of Set 2 | quatre cocos
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | tocopilla
# Processing Record 12 of Set 2 | zabid
# Processing Record 13 of Set 2 | yar-sale
# Processing Record 14 of Set 2 | antalaha
# Processing Record 15 of Set 2 | pinawa
# Processing Record 16 of Set 2 | palmer
# Processing Record 17 of Set 2 | high level
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | olafsvik
# Processing Record 20 of Set 2 | clyde river
# Processing Record 21 of Set 2 | kalmunai
# Processing Record 22 of Set 2 | bengkulu
# Processing Record 23 of Set 2 | lorengau
# Processing Record 24 of Set 2 | liwale
# Processing Record 25 of Set 2 | hailar
# Processing Record 26 of Set 2 | saint anthony
# Processing Record 27 of Set 2 | pimentel
# Processing Record 28 of Set 2 | husavik
# Processing Record 29 of Set 2 | esperance
# Processing Record 30 of Set 2 | port hardy
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | solnechnyy
# Processing Record 33 of Set 2 | erdenet
# Processing Record 34 of Set 2 | qixingtai
# Processing Record 35 of Set 2 | provideniya
# Processing Record 36 of Set 2 | witu
# Processing Record 37 of Set 2 | chokurdakh
# Processing Record 38 of Set 2 | puerto ayora
# Processing Record 39 of Set 2 | verkh-usugli
# Processing Record 40 of Set 2 | kodiak
# Processing Record 41 of Set 2 | mar del plata
# Processing Record 42 of Set 2 | tura
# Processing Record 43 of Set 2 | santo domingo
# Processing Record 44 of Set 2 | sao joao da barra
# Processing Record 45 of Set 2 | cabo san lucas
# Processing Record 46 of Set 2 | hovd
# Processing Record 47 of Set 2 | tuktoyaktuk
# Processing Record 48 of Set 2 | upernavik
# Processing Record 49 of Set 2 | mandurah
# Processing Record 50 of Set 2 | grand gaube
# Processing Record 1 of Set 3 | waitati
# Processing Record 2 of Set 3 | roma
# Processing Record 3 of Set 3 | tiksi
# Processing Record 4 of Set 3 | san antonio
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | avera
# Processing Record 7 of Set 3 | bubaque
# Processing Record 8 of Set 3 | beloha
# Processing Record 9 of Set 3 | simao
# Processing Record 10 of Set 3 | rocha
# Processing Record 11 of Set 3 | severo-kurilsk
# Processing Record 12 of Set 3 | bossangoa
# Processing Record 13 of Set 3 | williston
# Processing Record 14 of Set 3 | ilulissat
# Processing Record 15 of Set 3 | cedar city
# Processing Record 16 of Set 3 | goundam
# Processing Record 17 of Set 3 | vaini
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | frontera
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | sao filipe
# Processing Record 22 of Set 3 | la rochelle
# Processing Record 23 of Set 3 | port antonio
# Processing Record 24 of Set 3 | dikson
# Processing Record 25 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | khatanga
# Processing Record 28 of Set 3 | iqaluit
# Processing Record 29 of Set 3 | port blair
# Processing Record 30 of Set 3 | beidao
# Processing Record 31 of Set 3 | ternate
# Processing Record 32 of Set 3 | goderich
# Processing Record 33 of Set 3 | yanggu
# Processing Record 34 of Set 3 | oranjemund
# Processing Record 35 of Set 3 | lompoc
# Processing Record 36 of Set 3 | yuci
# Processing Record 37 of Set 3 | grindavik
# Processing Record 38 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 3 | saint george
# Processing Record 40 of Set 3 | concepcion
# Processing Record 41 of Set 3 | barabinsk
# Processing Record 42 of Set 3 | ixtapa
# Processing Record 43 of Set 3 | thompson
# Processing Record 44 of Set 3 | pangkalanbuun
# Processing Record 45 of Set 3 | narsaq
# Processing Record 46 of Set 3 | linhares
# Processing Record 47 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 48 of Set 3 | saskylakh
# Processing Record 49 of Set 3 | georgetown
# Processing Record 50 of Set 3 | harbour breton
# Processing Record 1 of Set 4 | zihuatanejo
# Processing Record 2 of Set 4 | beringovskiy
# Processing Record 3 of Set 4 | nishiwaki
# Processing Record 4 of Set 4 | tahe
# Processing Record 5 of Set 4 | tadine
# Processing Record 6 of Set 4 | castro
# Processing Record 7 of Set 4 | hami
# Processing Record 8 of Set 4 | altamont
# Processing Record 9 of Set 4 | general roca
# Processing Record 10 of Set 4 | kenora
# Processing Record 11 of Set 4 | coffs harbour
# Processing Record 12 of Set 4 | atessa
# Processing Record 13 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 4 | balkhash
# Processing Record 15 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 4 | ingham
# Processing Record 17 of Set 4 | sahrak
# City not found. Skipping...
# Processing Record 18 of Set 4 | takoradi
# Processing Record 19 of Set 4 | chuy
# Processing Record 20 of Set 4 | haines junction
# Processing Record 21 of Set 4 | alofi
# Processing Record 22 of Set 4 | avarua
# Processing Record 23 of Set 4 | ballina
# Processing Record 24 of Set 4 | naze
# Processing Record 25 of Set 4 | barguzin
# Processing Record 26 of Set 4 | rundu
# Processing Record 27 of Set 4 | bodden town
# Processing Record 28 of Set 4 | aquiraz
# Processing Record 29 of Set 4 | espanola
# Processing Record 30 of Set 4 | deputatskiy
# Processing Record 31 of Set 4 | pedasi
# Processing Record 32 of Set 4 | port lincoln
# Processing Record 33 of Set 4 | honiara
# Processing Record 34 of Set 4 | lempaala
# Processing Record 35 of Set 4 | gamba
# Processing Record 36 of Set 4 | port alfred
# Processing Record 37 of Set 4 | nouadhibou
# Processing Record 38 of Set 4 | kourou
# Processing Record 39 of Set 4 | portland
# Processing Record 40 of Set 4 | kununurra
# Processing Record 41 of Set 4 | faanui
# Processing Record 42 of Set 4 | damghan
# Processing Record 43 of Set 4 | alcains
# Processing Record 44 of Set 4 | baruun-urt
# Processing Record 45 of Set 4 | cidreira
# Processing Record 46 of Set 4 | loucovice
# Processing Record 47 of Set 4 | bima
# Processing Record 48 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 4 | dargaville
# Processing Record 50 of Set 4 | hirara
# Processing Record 1 of Set 5 | kyra
# Processing Record 2 of Set 5 | biak
# Processing Record 3 of Set 5 | rio grande
# Processing Record 4 of Set 5 | bairiki
# Processing Record 5 of Set 5 | bredasdorp
# Processing Record 6 of Set 5 | samarai
# Processing Record 7 of Set 5 | mahebourg
# Processing Record 8 of Set 5 | pisco
# Processing Record 9 of Set 5 | port elizabeth
# Processing Record 10 of Set 5 | carballo
# Processing Record 11 of Set 5 | sao jose da coroa grande
# Processing Record 12 of Set 5 | kloulklubed
# Processing Record 13 of Set 5 | port hedland
# Processing Record 14 of Set 5 | magadan
# Processing Record 15 of Set 5 | mogadishu
# Processing Record 16 of Set 5 | benjamin constant
# Processing Record 17 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 5 | stratford-upon-avon
# Processing Record 19 of Set 5 | casalpusterlengo
# Processing Record 20 of Set 5 | barcelona
# Processing Record 21 of Set 5 | batemans bay
# Processing Record 22 of Set 5 | zhuanghe
# Processing Record 23 of Set 5 | poya
# Processing Record 24 of Set 5 | namatanai
# Processing Record 25 of Set 5 | okhotsk
# Processing Record 26 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 5 | talnakh
# Processing Record 28 of Set 5 | sorland
# Processing Record 29 of Set 5 | lavrentiya
# Processing Record 30 of Set 5 | vila velha
# Processing Record 31 of Set 5 | mezen
# Processing Record 32 of Set 5 | marrakesh
# Processing Record 33 of Set 5 | pacific grove
# Processing Record 34 of Set 5 | huilong
# Processing Record 35 of Set 5 | la ciotat
# Processing Record 36 of Set 5 | fairview
# Processing Record 37 of Set 5 | vasto
# Processing Record 38 of Set 5 | henties bay
# Processing Record 39 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 5 | neepawa
# Processing Record 41 of Set 5 | bandarbeyla
# Processing Record 42 of Set 5 | lagos
# Processing Record 43 of Set 5 | afonso claudio
# Processing Record 44 of Set 5 | torbay
# Processing Record 45 of Set 5 | caxito
# Processing Record 46 of Set 5 | srikakulam
# Processing Record 47 of Set 5 | pangnirtung
# Processing Record 48 of Set 5 | coquimbo
# Processing Record 49 of Set 5 | manggar
# Processing Record 50 of Set 5 | waipawa
# Processing Record 1 of Set 6 | the valley
# Processing Record 2 of Set 6 | san carlos de bariloche
# Processing Record 3 of Set 6 | gallup
# Processing Record 4 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 6 | ekhabi
# Processing Record 6 of Set 6 | yuza
# Processing Record 7 of Set 6 | vodnyy
# Processing Record 8 of Set 6 | lasa
# Processing Record 9 of Set 6 | prado
# Processing Record 10 of Set 6 | novichikha
# Processing Record 11 of Set 6 | sekoma
# Processing Record 12 of Set 6 | kenai
# Processing Record 13 of Set 6 | vagamo
# Processing Record 14 of Set 6 | yarada
# Processing Record 15 of Set 6 | savyntsi
# Processing Record 16 of Set 6 | yumen
# Processing Record 17 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 6 | broome
# Processing Record 19 of Set 6 | mount gambier
# Processing Record 20 of Set 6 | ponta do sol
# Processing Record 21 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 6 | constitucion
# Processing Record 23 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 6 | maldonado
# Processing Record 25 of Set 6 | victoria
# Processing Record 26 of Set 6 | itarema
# Processing Record 27 of Set 6 | inyonga
# Processing Record 28 of Set 6 | san felipe
# Processing Record 29 of Set 6 | birin
# Processing Record 30 of Set 6 | abu dhabi
# Processing Record 31 of Set 6 | ust-tsilma
# Processing Record 32 of Set 6 | belmonte
# Processing Record 33 of Set 6 | severnyy
# Processing Record 34 of Set 6 | ziniare
# Processing Record 35 of Set 6 | byron bay
# Processing Record 36 of Set 6 | san quintin
# Processing Record 37 of Set 6 | belogorsk
# Processing Record 38 of Set 6 | geraldton
# Processing Record 39 of Set 6 | san cristobal
# Processing Record 40 of Set 6 | emba
# Processing Record 41 of Set 6 | charcas
# Processing Record 42 of Set 6 | svetlogorsk
# Processing Record 43 of Set 6 | cayenne
# Processing Record 44 of Set 6 | przhevalskoye
# Processing Record 45 of Set 6 | isangel
# Processing Record 46 of Set 6 | havre-saint-pierre
# Processing Record 47 of Set 6 | kieta
# Processing Record 48 of Set 6 | cockburn town
# Processing Record 49 of Set 6 | chegdomyn
# Processing Record 50 of Set 6 | conde
# Processing Record 1 of Set 7 | airai
# Processing Record 2 of Set 7 | poum
# Processing Record 3 of Set 7 | huarmey
# Processing Record 4 of Set 7 | half moon bay
# Processing Record 5 of Set 7 | hamilton
# Processing Record 6 of Set 7 | nhulunbuy
# Processing Record 7 of Set 7 | wewak
# Processing Record 8 of Set 7 | bukachacha
# Processing Record 9 of Set 7 | coahuayana
# Processing Record 10 of Set 7 | jieshou
# Processing Record 11 of Set 7 | dukat
# Processing Record 12 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 7 | jasper
# Processing Record 14 of Set 7 | west wendover
# Processing Record 15 of Set 7 | leningradskiy
# Processing Record 16 of Set 7 | san patricio
# Processing Record 17 of Set 7 | talara
# Processing Record 18 of Set 7 | saint-joseph
# Processing Record 19 of Set 7 | east london
# Processing Record 20 of Set 7 | sao felix do xingu
# Processing Record 21 of Set 7 | tres picos
# Processing Record 22 of Set 7 | korla
# Processing Record 23 of Set 7 | chunoyar
# Processing Record 24 of Set 7 | walvis bay
# Processing Record 25 of Set 7 | kargil
# Processing Record 26 of Set 7 | teknaf
# Processing Record 27 of Set 7 | carnarvon
# Processing Record 28 of Set 7 | general bravo
# Processing Record 29 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 7 | semily
# Processing Record 31 of Set 7 | barentu
# Processing Record 32 of Set 7 | jaramana
# City not found. Skipping...
# Processing Record 33 of Set 7 | saldanha
# Processing Record 34 of Set 7 | kendari
# Processing Record 35 of Set 7 | tukrah
# Processing Record 36 of Set 7 | ranong
# Processing Record 37 of Set 7 | vesoul
# Processing Record 38 of Set 7 | matara
# Processing Record 39 of Set 7 | la macarena
# Processing Record 40 of Set 7 | talcahuano
# Processing Record 41 of Set 7 | kruisfontein
# Processing Record 42 of Set 7 | ozu
# Processing Record 43 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 7 | west bay
# Processing Record 45 of Set 7 | thurso
# Processing Record 46 of Set 7 | swan hill
# Processing Record 47 of Set 7 | radhanpur
# Processing Record 48 of Set 7 | thongwa
# Processing Record 49 of Set 7 | klyuchi
# Processing Record 50 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 1 of Set 8 | ouro preto do oeste
# Processing Record 2 of Set 8 | maraba
# Processing Record 3 of Set 8 | uong bi
# Processing Record 4 of Set 8 | monte azul
# Processing Record 5 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 8 | wajima
# Processing Record 7 of Set 8 | ujjain
# Processing Record 8 of Set 8 | severodvinsk
# Processing Record 9 of Set 8 | tazovskiy
# Processing Record 10 of Set 8 | ahipara
# Processing Record 11 of Set 8 | marsa matruh
# Processing Record 12 of Set 8 | havoysund
# Processing Record 13 of Set 8 | alekseyevsk
# Processing Record 14 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 15 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 8 | muros
# Processing Record 17 of Set 8 | san isidro
# Processing Record 18 of Set 8 | nizhneudinsk
# Processing Record 19 of Set 8 | daru
# Processing Record 20 of Set 8 | port-gentil
# Processing Record 21 of Set 8 | atar
# Processing Record 22 of Set 8 | zvishavane
# Processing Record 23 of Set 8 | homer
# Processing Record 24 of Set 8 | ardabil
# Processing Record 25 of Set 8 | owando
# Processing Record 26 of Set 8 | la gomera
# Processing Record 27 of Set 8 | tarbes
# Processing Record 28 of Set 8 | baboua
# City not found. Skipping...
# Processing Record 29 of Set 8 | creemore
# Processing Record 30 of Set 8 | zarubino
# Processing Record 31 of Set 8 | katobu
# Processing Record 32 of Set 8 | ancud
# Processing Record 33 of Set 8 | bereda
# Processing Record 34 of Set 8 | aklavik
# Processing Record 35 of Set 8 | caldas da rainha
# Processing Record 36 of Set 8 | turka
# Processing Record 37 of Set 8 | nishihara
# Processing Record 38 of Set 8 | sao sebastiao
# Processing Record 39 of Set 8 | sakakah
# Processing Record 40 of Set 8 | mehriz
# Processing Record 41 of Set 8 | concepcion de buenos aires
# Processing Record 42 of Set 8 | serenje
# Processing Record 43 of Set 8 | sola
# Processing Record 44 of Set 8 | burica
# City not found. Skipping...
# Processing Record 45 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 8 | kotelnikovo
# Processing Record 48 of Set 8 | bilibino
# Processing Record 49 of Set 8 | leesburg
# Processing Record 50 of Set 8 | hobyo
# Processing Record 1 of Set 9 | bonthe
# Processing Record 2 of Set 9 | ilorin
# Processing Record 3 of Set 9 | cherskiy
# Processing Record 4 of Set 9 | lypova dolyna
# Processing Record 5 of Set 9 | praia
# Processing Record 6 of Set 9 | cam pha
# City not found. Skipping...
# Processing Record 7 of Set 9 | bridlington
# Processing Record 8 of Set 9 | richards bay
# Processing Record 9 of Set 9 | warrington
# Processing Record 10 of Set 9 | calama
# Processing Record 11 of Set 9 | shingu
# Processing Record 12 of Set 9 | meadow lake
# Processing Record 13 of Set 9 | sur
# Processing Record 14 of Set 9 | batticaloa
# Processing Record 15 of Set 9 | ozerki
# Processing Record 16 of Set 9 | awjilah
# Processing Record 17 of Set 9 | ketchikan
# Processing Record 18 of Set 9 | eureka
# Processing Record 19 of Set 9 | port moresby
# Processing Record 20 of Set 9 | chumikan
# Processing Record 21 of Set 9 | pallasovka
# Processing Record 22 of Set 9 | tezu
# Processing Record 23 of Set 9 | palapye
# Processing Record 24 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 25 of Set 9 | riyadh
# Processing Record 26 of Set 9 | usinsk
# Processing Record 27 of Set 9 | kanniyakumari
# Processing Record 28 of Set 9 | kralendijk
# Processing Record 29 of Set 9 | maningrida
# Processing Record 30 of Set 9 | cristalina
# Processing Record 31 of Set 9 | malkangiri
# Processing Record 32 of Set 9 | carutapera
# Processing Record 33 of Set 9 | russell
# Processing Record 34 of Set 9 | lucapa
# Processing Record 35 of Set 9 | jiuquan
# Processing Record 36 of Set 9 | sembe
# Processing Record 37 of Set 9 | nsukka
# Processing Record 38 of Set 9 | menongue
# Processing Record 39 of Set 9 | belaya gora
# Processing Record 40 of Set 9 | makakilo city
# Processing Record 41 of Set 9 | khalkhal
# Processing Record 42 of Set 9 | laguna
# Processing Record 43 of Set 9 | santarem
# Processing Record 44 of Set 9 | aleksin
# Processing Record 45 of Set 9 | pitimbu
# Processing Record 46 of Set 9 | grand-santi
# Processing Record 47 of Set 9 | gladstone
# Processing Record 48 of Set 9 | mount prospect
# Processing Record 49 of Set 9 | rio gallegos
# Processing Record 50 of Set 9 | villers-le-bouillet
# Processing Record 1 of Set 10 | abengourou
# Processing Record 2 of Set 10 | beyneu
# Processing Record 3 of Set 10 | mahibadhoo
# Processing Record 4 of Set 10 | kamenka
# Processing Record 5 of Set 10 | komsomolskiy
# Processing Record 6 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 7 of Set 10 | wanning
# Processing Record 8 of Set 10 | prescott
# Processing Record 9 of Set 10 | yulara
# Processing Record 10 of Set 10 | payakumbuh
# Processing Record 11 of Set 10 | guane
# Processing Record 12 of Set 10 | neyshabur
# Processing Record 13 of Set 10 | farah
# Processing Record 14 of Set 10 | lagoa
# Processing Record 15 of Set 10 | puerto quijarro
# Processing Record 16 of Set 10 | buzmeyin
# Processing Record 17 of Set 10 | sechura
# Processing Record 18 of Set 10 | sistranda
# Processing Record 19 of Set 10 | kampot
# Processing Record 20 of Set 10 | nador
# Processing Record 21 of Set 10 | ossora
# Processing Record 22 of Set 10 | charters towers
# Processing Record 23 of Set 10 | labytnangi
# Processing Record 24 of Set 10 | sharjah
# Processing Record 25 of Set 10 | trelew
# Processing Record 26 of Set 10 | kem
# Processing Record 27 of Set 10 | egvekinot
# Processing Record 28 of Set 10 | atasu
# Processing Record 29 of Set 10 | lata
# Processing Record 30 of Set 10 | baykit
# Processing Record 31 of Set 10 | pontiac
# Processing Record 32 of Set 10 | maketu
# Processing Record 33 of Set 10 | tarauaca
# Processing Record 34 of Set 10 | conceicao da barra
# Processing Record 35 of Set 10 | emirdag
# Processing Record 36 of Set 10 | dongsheng
# Processing Record 37 of Set 10 | adrar
# Processing Record 38 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 10 | slupsk
# Processing Record 40 of Set 10 | izazi
# Processing Record 41 of Set 10 | coatzintla
# Processing Record 42 of Set 10 | union
# Processing Record 43 of Set 10 | college
# Processing Record 44 of Set 10 | serebryansk
# Processing Record 45 of Set 10 | ayan
# Processing Record 46 of Set 10 | gerede
# Processing Record 47 of Set 10 | touros
# Processing Record 48 of Set 10 | port shepstone
# Processing Record 49 of Set 10 | nurota
# Processing Record 50 of Set 10 | berlevag
# Processing Record 1 of Set 11 | coihaique
# Processing Record 2 of Set 11 | jacareacanga
# Processing Record 3 of Set 11 | tabou
# Processing Record 4 of Set 11 | garden city
# Processing Record 5 of Set 11 | slave lake
# Processing Record 6 of Set 11 | rio tercero
# Processing Record 7 of Set 11 | beppu
# Processing Record 8 of Set 11 | asfi
# Processing Record 9 of Set 11 | santa maria
# Processing Record 10 of Set 11 | dingle
# Processing Record 11 of Set 11 | ostersund
# Processing Record 12 of Set 11 | broken hill
# Processing Record 13 of Set 11 | betafo
# Processing Record 14 of Set 11 | narrabri
# Processing Record 15 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 16 of Set 11 | pecsvarad
# Processing Record 17 of Set 11 | male
# Processing Record 18 of Set 11 | uroteppa
# City not found. Skipping...
# Processing Record 19 of Set 11 | locri
# Processing Record 20 of Set 11 | guerrero negro
# Processing Record 21 of Set 11 | sozimskiy
# Processing Record 22 of Set 11 | tautira
# Processing Record 23 of Set 11 | emet
# Processing Record 24 of Set 11 | aden
# Processing Record 25 of Set 11 | mecca
# Processing Record 26 of Set 11 | anekal
# Processing Record 27 of Set 11 | uddevalla
# Processing Record 28 of Set 11 | bainbridge
# Processing Record 29 of Set 11 | pierre
# Processing Record 30 of Set 11 | qaqortoq
# Processing Record 31 of Set 11 | abonnema
# Processing Record 32 of Set 11 | la ronge
# Processing Record 33 of Set 11 | brewster
# Processing Record 34 of Set 11 | abay
# Processing Record 35 of Set 11 | rincon
# Processing Record 36 of Set 11 | kanye
# Processing Record 37 of Set 11 | port augusta
# Processing Record 38 of Set 11 | monrovia
# Processing Record 39 of Set 11 | lianzhou
# Processing Record 40 of Set 11 | rantepao
# Processing Record 41 of Set 11 | nemuro
# Processing Record 42 of Set 11 | wonosari
# Processing Record 43 of Set 11 | deloraine
# Processing Record 44 of Set 11 | pontes e lacerda
# Processing Record 45 of Set 11 | namtsy
# Processing Record 46 of Set 11 | bondoukou
# Processing Record 47 of Set 11 | santa cruz
# Processing Record 48 of Set 11 | chilca
# Processing Record 49 of Set 11 | praya
# Processing Record 50 of Set 11 | bani walid
# Processing Record 1 of Set 12 | kirovsk
# Processing Record 2 of Set 12 | karratha
# Processing Record 3 of Set 12 | okakarara
# Processing Record 4 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 12 | cochabamba
# Processing Record 6 of Set 12 | hambantota
# Processing Record 7 of Set 12 | mafinga
# Processing Record 8 of Set 12 | luganville
# Processing Record 9 of Set 12 | te anau
# Processing Record 10 of Set 12 | halifax
# Processing Record 11 of Set 12 | maceio
# Processing Record 12 of Set 12 | cap malheureux
# Processing Record 13 of Set 12 | aksarka
# Processing Record 14 of Set 12 | sarakhs
# Processing Record 15 of Set 12 | arawa
# Processing Record 16 of Set 12 | manokwari
# Processing Record 17 of Set 12 | codrington
# Processing Record 18 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 12 | denpasar
# Processing Record 20 of Set 12 | buraydah
# Processing Record 21 of Set 12 | taft
# Processing Record 22 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 12 | seara
# Processing Record 24 of Set 12 | arandis
# Processing Record 25 of Set 12 | oron
# Processing Record 26 of Set 12 | akyab
# Processing Record 27 of Set 12 | arlit
# Processing Record 28 of Set 12 | lobva
# Processing Record 29 of Set 12 | say
# Processing Record 30 of Set 12 | panama city
# Processing Record 31 of Set 12 | dalvik
# Processing Record 32 of Set 12 | nassau
# Processing Record 33 of Set 12 | mizdah
# Processing Record 34 of Set 12 | gizo
# Processing Record 35 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 36 of Set 12 | sijunjung
# Processing Record 37 of Set 12 | zhangye
# Processing Record 38 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 12 | powell river
# City not found. Skipping...
# Processing Record 40 of Set 12 | matagami
# City not found. Skipping...
# Processing Record 41 of Set 12 | andros town
# City not found. Skipping...
# Processing Record 42 of Set 12 | san andres
# City not found. Skipping...
# Processing Record 43 of Set 12 | thalgau
# City not found. Skipping...
# Processing Record 44 of Set 12 | kathmandu
# City not found. Skipping...
# Processing Record 45 of Set 12 | santa maria da vitoria
# City not found. Skipping...
# Processing Record 46 of Set 12 | ongandjera
# City not found. Skipping...
# Processing Record 47 of Set 12 | san pedro carcha
# City not found. Skipping...
# Processing Record 48 of Set 12 | mabaruma
# City not found. Skipping...
# Processing Record 49 of Set 12 | stromness
# City not found. Skipping...
# Processing Record 50 of Set 12 | kushima
# City not found. Skipping...
# Processing Record 1 of Set 13 | takayama
# Processing Record 2 of Set 13 | guna
# Processing Record 3 of Set 13 | hatillo
# Processing Record 4 of Set 13 | durazno
# Processing Record 5 of Set 13 | sabalgarh
# Processing Record 6 of Set 13 | mambajao
# Processing Record 7 of Set 13 | yatou
# Processing Record 8 of Set 13 | puerto colombia
# Processing Record 9 of Set 13 | golden
# Processing Record 10 of Set 13 | valparaiso
# Processing Record 11 of Set 13 | muisne
# Processing Record 12 of Set 13 | kysyl-syr
# Processing Record 13 of Set 13 | batagay
# Processing Record 14 of Set 13 | raymondville
# Processing Record 15 of Set 13 | kanker
# Processing Record 16 of Set 13 | kavaratti
# Processing Record 17 of Set 13 | tolaga bay
# Processing Record 18 of Set 13 | pafos
# Processing Record 19 of Set 13 | masuguru
# Processing Record 20 of Set 13 | johnson city
# Processing Record 21 of Set 13 | witbank
# Processing Record 22 of Set 13 | duku
# Processing Record 23 of Set 13 | wanaka
# Processing Record 24 of Set 13 | faya
# Processing Record 25 of Set 13 | itapetinga
# Processing Record 26 of Set 13 | novyy urengoy
# Processing Record 27 of Set 13 | taoudenni
# Processing Record 28 of Set 13 | sept-iles
# Processing Record 29 of Set 13 | marzuq
# Processing Record 30 of Set 13 | hun
# Processing Record 31 of Set 13 | hammerfest
# Processing Record 32 of Set 13 | margate
# Processing Record 33 of Set 13 | shimoda
# Processing Record 34 of Set 13 | vestmannaeyjar
# Processing Record 35 of Set 13 | punjai puliyampatti
# Processing Record 36 of Set 13 | turtas
# Processing Record 37 of Set 13 | ouadda
# Processing Record 38 of Set 13 | el alto
# Processing Record 39 of Set 13 | tateyama
# Processing Record 40 of Set 13 | binga
# Processing Record 41 of Set 13 | nizwa
# Processing Record 42 of Set 13 | waverly
# Processing Record 43 of Set 13 | guia de isora
# Processing Record 44 of Set 13 | kesinga
# Processing Record 45 of Set 13 | mersin
# Processing Record 46 of Set 13 | bakchar
# Processing Record 47 of Set 13 | umm lajj
# Processing Record 48 of Set 13 | muriwai beach
# Processing Record 49 of Set 13 | wurzen
# Processing Record 50 of Set 13 | bemidji
# Processing Record 1 of Set 14 | benguela
# Processing Record 2 of Set 14 | mackenzie
# Processing Record 3 of Set 14 | puerto leguizamo
# Processing Record 4 of Set 14 | teacapan
# Processing Record 5 of Set 14 | okha
# Processing Record 6 of Set 14 | tulum
# Processing Record 7 of Set 14 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 14 | guatire
# Processing Record 9 of Set 14 | cajati
# Processing Record 10 of Set 14 | uyar
# Processing Record 11 of Set 14 | gzhatsk
# City not found. Skipping...
# Processing Record 12 of Set 14 | mount isa
# Processing Record 13 of Set 14 | cilegon
# Processing Record 14 of Set 14 | zanatepec
# City not found. Skipping...
# Processing Record 15 of Set 14 | avdiyivka
# Processing Record 16 of Set 14 | acapulco
# Processing Record 17 of Set 14 | galdar
# Processing Record 18 of Set 14 | pevek
# Processing Record 19 of Set 14 | fukuma
# Processing Record 20 of Set 14 | marsh harbour
# Processing Record 21 of Set 14 | lorsch
# Processing Record 22 of Set 14 | duz
# City not found. Skipping...
# Processing Record 23 of Set 14 | pamfila
# Processing Record 24 of Set 14 | katima mulilo
# Processing Record 25 of Set 14 | kirksville
# Processing Record 26 of Set 14 | marv dasht
# City not found. Skipping...
# Processing Record 27 of Set 14 | cranendonck
# Processing Record 28 of Set 14 | arroyohondo
# Processing Record 29 of Set 14 | meulaboh
# Processing Record 30 of Set 14 | la asuncion
# Processing Record 31 of Set 14 | shouguang
# Processing Record 32 of Set 14 | tiarei
# Processing Record 33 of Set 14 | troitskoye
# Processing Record 34 of Set 14 | kimberley
# Processing Record 35 of Set 14 | tyrma
# Processing Record 36 of Set 14 | temiscaming
# Processing Record 37 of Set 14 | hearst
# Processing Record 38 of Set 14 | alappuzha
# Processing Record 39 of Set 14 | saint-pierre
# Processing Record 40 of Set 14 | prince rupert
# Processing Record 41 of Set 14 | hede
# Processing Record 42 of Set 14 | port-de-paix
# City not found. Skipping...
# Processing Record 43 of Set 14 | tommot
# Processing Record 44 of Set 14 | madingou
# Processing Record 45 of Set 14 | pochutla
# Processing Record 46 of Set 14 | bahia blanca
# Processing Record 47 of Set 14 | nelson bay
# Processing Record 48 of Set 14 | slobodskoy
# Processing Record 49 of Set 14 | inhambane
# Processing Record 50 of Set 14 | nargana
# Processing Record 1 of Set 15 | paamiut
# Processing Record 2 of Set 15 | orbetello
# Processing Record 3 of Set 15 | vanimo
# Processing Record 4 of Set 15 | ca mau
# Processing Record 5 of Set 15 | mugur-aksy
# Processing Record 6 of Set 15 | odweyne
# Processing Record 7 of Set 15 | saint-prosper
# Processing Record 8 of Set 15 | santa rosa
# Processing Record 9 of Set 15 | harper
# Processing Record 10 of Set 15 | marovoay
# Processing Record 11 of Set 15 | luwuk
# Processing Record 12 of Set 15 | esso
# Processing Record 13 of Set 15 | jinchengjiang
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 650

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0       Rikitea -23.1203 -134.9692     20.54          few clouds        66
# 1          Lebu -37.6167  -73.6500     11.17     overcast clouds        85
# 2       Salalah  17.0151   54.0924     25.25     overcast clouds        81
# 3  Longyearbyen  78.2186   15.6401      3.91          few clouds        75
# 4    Nikolskoye  59.7035   30.7861      8.94     overcast clouds        98
# 5       Kahului  20.8947 -156.4700     31.01    scattered clouds        68
# 6         Bluff -46.6000  168.3333      6.56     overcast clouds        63
# 7     Bathsheba  13.2167  -59.5167     27.34       broken clouds        83
# 8       Sarauli  28.5000   79.1000     22.44       broken clouds        92
# 9  Punta Arenas -53.1500  -70.9167      9.06          light rain        66
#
#    Cloudiness  Wind Speed Country
# 0          12        9.63      PF
# 1         100        3.65      CL
# 2          96        1.65      OM
# 3          20        6.69      SJ
# 4          96        3.16      RU
# 5          40        8.23      US
# 6          96       10.35      NZ
# 7          75        6.69      BB
# 8          51        3.38      IN
# 9          75        4.12      CL

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[columns]

# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea      PF -23.1203 -134.9692     20.54        66          12
# 1          Lebu      CL -37.6167  -73.6500     11.17        85         100
# 2       Salalah      OM  17.0151   54.0924     25.25        81          96
# 3  Longyearbyen      SJ  78.2186   15.6401      3.91        75          20
# 4    Nikolskoye      RU  59.7035   30.7861      8.94        98          96
#
#    Wind Speed Current Description
# 0        9.63          few clouds
# 1        3.65     overcast clouds
# 2        1.65     overcast clouds
# 3        6.69          few clouds
# 4        3.16     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
#i have to slightly change the below
output_data_file = "Weather_Database\WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
